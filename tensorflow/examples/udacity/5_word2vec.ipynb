# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'anarchism', 'term', 'originated', 'originated', 'as', 'term', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.741567
# Nearest to no: rte, immunoglobulins, seedless, gzip, epitaph, coro, beheaded, beginners,
# Nearest to at: edi, bombed, vincennes, domitius, sun, desalination, bolo, annexes,
# Nearest to but: footwork, aurelian, ehr, vse, murmur, cube, moravian, artiodactyla,
# Nearest to some: prank, overlords, waw, brugge, curator, deprivation, cubes, mecca,
# Nearest to were: tract, gottlieb, fasting, stabilize, distress, granite, musketeers, aloha,
# Nearest to eight: regulation, canter, provincias, grouse, boo, prophet, roma, forcibly,
# Nearest to they: scene, ada, overlord, entanglement, lexeme, cams, withdrawals, multipoint,
# Nearest to an: jayne, magma, jes, hippo, banda, scenery, prds, unsuspecting,
# Nearest to up: tricks, probabilities, quranic, wie, immortalised, pu, eduard, priscus,
# Nearest to it: unscientific, cosworth, volker, joss, petrus, saw, cura, andres,
# Nearest to between: luce, ncsa, majority, gobi, lancastrian, meg, loudly, pumped,
# Nearest to who: chance, perfection, daugava, bradbury, guilt, erika, cram, adolfo,
# Nearest to american: rajasthan, mrnas, beak, miserable, find, individuality, tool, tlatelolco,
# Nearest to have: upa, bankrupt, echolocation, myself, shelves, clements, thermopylae, aloud,
# Nearest to will: michelin, consults, pseudonym, corran, irvine, phenomenon, log, livestock,
# Nearest to was: peshawar, heiden, noether, actual, devoting, indium, prasad, chapter,
# Average loss at step 2000: 4.361980
# Average loss at step 4000: 3.867488
# Average loss at step 6000: 3.784144
# Average loss at step 8000: 3.689263
# Average loss at step 10000: 3.615092
# Nearest to no: rte, seedless, antihydrogen, valued, very, casement, phobia, immunoglobulins,
# Nearest to at: in, by, on, bombed, stump, of, uri, pontchartrain,
# Nearest to but: nul, diffie, simultaneous, tehran, emphasising, fayetteville, moravian, unicameral,
# Nearest to some: many, other, unelected, prank, these, them, decrypt, coimbra,
# Nearest to were: are, was, have, and, degrees, masai, ignite, guyer,
# Nearest to eight: six, nine, five, four, seven, three, zero, two,
# Nearest to they: he, it, not, soloists, we, there, cubs, rulebook,
# Nearest to an: intonation, flap, annalen, the, graft, hess, immortals, intelligencer,
# Nearest to up: tricks, quranic, wie, downfall, janis, intimidation, probabilities, saxophones,
# Nearest to it: he, there, this, not, they, which, that, instrumentalist,
# Nearest to between: with, altercation, spellings, lafcadio, luce, althing, teh, optimizing,
# Nearest to who: he, rajput, not, matriculation, celebrity, still, also, they,
# Nearest to american: french, rajasthan, avercamp, flipping, technicality, leutze, vogue, and,
# Nearest to have: had, be, has, westeros, are, were, cod, steve,
# Nearest to will: would, log, michelin, corran, dell, must, may, can,
# Nearest to was: is, had, by, has, were, be, aryeh, devoting,
# Average loss at step 12000: 3.605497
# Average loss at step 14000: 3.570567
# Average loss at step 16000: 3.409459
# Average loss at step 18000: 3.462707
# Average loss at step 20000: 3.537956
# Nearest to no: rte, tobruk, palliative, there, valued, ifs, hemphill, rica,
# Nearest to at: in, eared, stump, uri, on, yeasts, shielding, from,
# Nearest to but: however, though, that, and, which, iarc, while, preprocessing,
# Nearest to some: many, these, other, unelected, the, their, prank, gm,
# Nearest to were: are, was, had, have, be, degrees, by, is,
# Nearest to eight: seven, nine, six, four, five, three, two, zero,
# Nearest to they: he, there, we, it, who, not, you, catholicism,
# Nearest to an: the, intonation, jayne, jes, annalen, recites, graft, oman,
# Nearest to up: tricks, quranic, intimidation, probabilities, janis, wie, return, him,
# Nearest to it: he, there, this, they, which, she, not, often,
# Nearest to between: with, from, spellings, into, unpaved, altercation, hyllus, over,
# Nearest to who: he, which, also, they, celebrity, still, connelly, daugava,
# Nearest to american: french, english, crushed, bewitched, technicality, british, intensities, flipping,
# Nearest to have: had, has, be, were, westeros, are, serenity, receive,
# Nearest to will: would, can, may, must, cannot, could, to, yet,
# Nearest to was: is, has, had, were, be, aryeh, are, been,
# Average loss at step 22000: 3.497068
# Average loss at step 24000: 3.490962
# Average loss at step 26000: 3.481535
# Average loss at step 28000: 3.479000
# Average loss at step 30000: 3.497928
# Nearest to no: rte, a, warmed, sabrina, ocp, any, bihari, tha,
# Nearest to at: in, stump, during, bmx, when, uri, on, lamarck,
# Nearest to but: however, and, while, although, blenheim, which, that, though,
# Nearest to some: many, these, several, other, gm, various, most, all,
# Nearest to were: are, was, have, had, is, been, hamill, by,
# Nearest to eight: nine, seven, five, six, four, three, zero, two,
# Nearest to they: there, we, he, it, who, you, not, she,
# Nearest to an: jes, cyclops, annalen, intonation, sociologist, gutnish, jayne, intelligencer,
# Nearest to up: him, tricks, probabilities, thirds, impregnated, cutting, them, janis,
# Nearest to it: he, there, she, they, this, which, not, annex,
# Nearest to between: with, from, into, spellings, against, over, tangents, unpaved,
# Nearest to who: he, they, which, also, she, celebrity, already, tychonoff,
# Nearest to american: french, english, british, australian, spanish, bewitched, giver, flipping,
# Nearest to have: had, has, are, were, be, westeros, dembski, serenity,
# Nearest to will: would, can, may, must, could, cannot, should, to,
# Nearest to was: is, had, were, has, been, aryeh, became, by,
# Average loss at step 32000: 3.499648
# Average loss at step 34000: 3.495365
# Average loss at step 36000: 3.452197
# Average loss at step 38000: 3.305566
# Average loss at step 40000: 3.422907
# Nearest to no: any, rte, bihari, sabrina, warmed, ocp, things, bag,
# Nearest to at: during, interchanges, stump, imperfectly, azeotrope, in, near, on,
# Nearest to but: however, and, although, while, though, outwardly, when, which,
# Nearest to some: many, these, several, any, gm, both, various, most,
# Nearest to were: are, was, have, had, been, be, being, although,
# Nearest to eight: nine, seven, six, four, five, three, zero, one,
# Nearest to they: we, there, he, you, it, she, who, these,
# Nearest to an: jayne, jes, the, cyclops, graft, gravestone, approximation, dfts,
# Nearest to up: him, them, out, probabilities, tricks, impregnated, cutting, sign,
# Nearest to it: he, there, she, they, this, which, anarchism, not,
# Nearest to between: with, into, over, against, petrochemicals, from, hyllus, spellings,
# Nearest to who: he, which, they, that, often, also, tychonoff, weathered,
# Nearest to american: british, english, french, australian, bewitched, crushed, giver, spanish,
# Nearest to have: had, has, are, were, be, dembski, westeros, assembled,
# Nearest to will: would, can, must, may, could, cannot, should, might,
# Nearest to was: is, were, has, had, aryeh, became, been, be,
# Average loss at step 42000: 3.437030
# Average loss at step 44000: 3.451453
# Average loss at step 46000: 3.446299
# Average loss at step 48000: 3.354795
# Average loss at step 50000: 3.384917
# Nearest to no: any, warmed, aires, rte, sabrina, bag, bihari, tha,
# Nearest to at: during, in, wholeheartedly, interchanges, near, stump, on, yeasts,
# Nearest to but: however, although, when, while, though, and, which, whitey,
# Nearest to some: many, these, several, various, gm, both, other, most,
# Nearest to were: are, was, have, be, had, being, been, these,
# Nearest to eight: six, nine, seven, four, five, three, zero, two,
# Nearest to they: he, there, we, it, she, you, who, these,
# Nearest to an: the, dfts, cyclops, jes, jayne, graft, tramways, dvb,
# Nearest to up: out, them, him, off, probabilities, mongolian, cutting, tricks,
# Nearest to it: he, there, she, this, they, annex, often, usually,
# Nearest to between: with, hyllus, from, spellings, into, within, over, among,
# Nearest to who: he, which, never, she, they, tychonoff, also, doped,
# Nearest to american: english, french, british, international, australian, gutenberg, italian, crushed,
# Nearest to have: had, has, be, were, are, having, dembski, westeros,
# Nearest to will: would, can, could, must, may, should, cannot, might,
# Nearest to was: is, were, has, had, became, be, progressing, been,
# Average loss at step 52000: 3.439088
# Average loss at step 54000: 3.422522
# Average loss at step 56000: 3.437662
# Average loss at step 58000: 3.401583
# Average loss at step 60000: 3.391761
# Nearest to no: any, aires, warmed, sabrina, a, sceptre, rte, some,
# Nearest to at: during, in, near, wholeheartedly, stump, valyria, termites, certification,
# Nearest to but: however, and, although, though, while, exist, which, when,
# Nearest to some: many, several, these, various, gm, all, any, most,
# Nearest to were: are, was, had, have, those, been, although, including,
# Nearest to eight: nine, six, seven, four, five, three, zero, one,
# Nearest to they: we, there, he, you, she, it, not, these,
# Nearest to an: jayne, dfts, graft, impair, another, jes, tramways, forestall,
# Nearest to up: out, him, them, off, down, probabilities, back, mongolian,
# Nearest to it: there, he, she, this, they, which, often, actually,
# Nearest to between: with, over, among, within, from, into, against, tangents,
# Nearest to who: he, never, still, she, which, tychonoff, also, already,
# Nearest to american: british, english, gutenberg, italian, french, australian, international, giver,
# Nearest to have: had, has, are, having, were, be, dembski, westeros,
# Nearest to will: would, must, can, could, may, should, cannot, might,
# Nearest to was: is, had, were, became, aryeh, has, been, be,
# Average loss at step 62000: 3.242293
# Average loss at step 64000: 3.252303
# Average loss at step 66000: 3.401303
# Average loss at step 68000: 3.392170
# Average loss at step 70000: 3.352403
# Nearest to no: warmed, any, sabrina, serious, anything, bene, alaric, bihari,
# Nearest to at: during, stump, wholeheartedly, in, on, bmx, confuse, promiscuous,
# Nearest to but: however, although, though, while, which, and, burnley, than,
# Nearest to some: many, several, these, various, all, certain, most, any,
# Nearest to were: are, was, had, have, be, been, those, being,
# Nearest to eight: nine, six, seven, four, five, three, zero, one,
# Nearest to they: we, there, he, you, it, she, who, taklamakan,
# Nearest to an: cyclops, forestall, dfts, approximation, intelligencer, impair, jayne, another,
# Nearest to up: them, out, off, him, down, mongolian, impregnated, layer,
# Nearest to it: he, she, there, this, they, still, also, we,
# Nearest to between: with, among, within, from, tangents, dissent, ancestry, into,
# Nearest to who: he, tychonoff, never, they, still, copycat, she, weathered,
# Nearest to american: british, english, italian, french, australian, gutenberg, international, flipping,
# Nearest to have: had, has, are, were, be, dembski, having, include,
# Nearest to will: would, must, could, can, may, should, cannot, might,
# Nearest to was: is, were, has, had, progressing, been, be, aryeh,
# Average loss at step 72000: 3.375793
# Average loss at step 74000: 3.345705
# Average loss at step 76000: 3.319062
# Average loss at step 78000: 3.346848
# Average loss at step 80000: 3.378536
# Nearest to no: warmed, bihari, parque, sabrina, any, tha, sleepless, little,
# Nearest to at: in, stump, during, on, hairless, from, almost, shielding,
# Nearest to but: however, although, while, though, and, than, unsigned, when,
# Nearest to some: many, several, most, various, these, both, certain, any,
# Nearest to were: are, was, had, have, be, been, being, although,
# Nearest to eight: nine, six, seven, five, four, three, zero, two,
# Nearest to they: we, he, there, you, she, it, who, soon,
# Nearest to an: cyclops, jayne, escher, impair, graft, forestall, meow, curtains,
# Nearest to up: out, off, them, him, down, impregnated, mongolian, back,
# Nearest to it: he, she, there, this, they, never, sometimes, actually,
# Nearest to between: within, among, over, around, with, tangents, through, ancestry,
# Nearest to who: he, she, never, still, they, cantilever, often, which,
# Nearest to american: british, french, australian, international, italian, canadian, irish, english,
# Nearest to have: had, has, be, are, were, having, include, dembski,
# Nearest to will: would, must, could, can, should, may, cannot, might,
# Nearest to was: is, were, became, has, had, aryeh, be, being,
# Average loss at step 82000: 3.407236
# Average loss at step 84000: 3.407469
# Average loss at step 86000: 3.386371
# Average loss at step 88000: 3.350231
# Average loss at step 90000: 3.361222
# Nearest to no: any, warmed, little, sabrina, only, bihari, than, serious,
# Nearest to at: during, near, in, on, beyond, under, stump, georgy,
# Nearest to but: however, although, while, and, though, which, she, he,
# Nearest to some: many, several, these, certain, both, various, most, any,
# Nearest to were: are, had, was, have, while, although, those, these,
# Nearest to eight: seven, six, nine, five, four, three, zero, one,
# Nearest to they: we, he, there, you, she, it, taklamakan, who,
# Nearest to an: jayne, escher, another, cyclops, dfts, outage, recites, impair,
# Nearest to up: out, off, them, him, back, down, mongolian, together,
# Nearest to it: he, she, there, this, they, itself, actually, thus,
# Nearest to between: with, among, within, tangents, around, into, over, through,
# Nearest to who: he, never, she, still, which, often, they, generally,
# Nearest to american: british, italian, french, australian, canadian, irish, russian, english,
# Nearest to have: had, has, be, were, are, having, include, dembski,
# Nearest to will: would, must, could, can, may, should, might, cannot,
# Nearest to was: is, had, became, were, has, be, been, marquette,
# Average loss at step 92000: 3.396426
# Average loss at step 94000: 3.257117
# Average loss at step 96000: 3.361046
# Average loss at step 98000: 3.238635
# Average loss at step 100000: 3.355622
# Nearest to no: warmed, any, little, bihari, another, ulysses, only, rte,
# Nearest to at: during, on, near, in, wholeheartedly, beyond, stump, interchanges,
# Nearest to but: however, although, and, while, though, which, when, than,
# Nearest to some: many, several, these, various, any, certain, gm, all,
# Nearest to were: are, have, was, these, had, those, although, including,
# Nearest to eight: nine, seven, four, six, five, three, zero, two,
# Nearest to they: we, he, there, you, she, it, taklamakan, i,
# Nearest to an: jayne, gravestone, another, escher, intelligencer, soaking, cyclops, meow,
# Nearest to up: out, off, him, them, back, down, mongolian, wagoner,
# Nearest to it: he, she, this, there, they, generally, actually, often,
# Nearest to between: with, among, over, within, through, tangents, hyi, into,
# Nearest to who: he, never, still, she, also, actually, dylan, which,
# Nearest to american: british, canadian, australian, french, sanitarium, crushed, italian, technicality,
# Nearest to have: had, has, were, are, contain, be, include, tend,
# Nearest to will: would, must, could, can, may, should, might, cannot,
# Nearest to was: is, became, were, had, has, been, when, aryeh,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
# Out:
# /Users/AlanYAN/anaconda/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
# CBOW

def generate_CBOW_batch(batch_size, skip_window):
  assert batch_size % skip_window == 0
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  label = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  for i in xrange(batch_size//skip_window//2):
    target = 2*i+skip_window
    for j in xrange(skip_window):
        batch[i*skip_window*2+j] = data[target-j-1]
        label[i*skip_window*2+j] = data[target]
    for j in xrange(skip_window):
        batch[(i*2+1)*skip_window+j] = data[target+j+1]
        label[(i*2+1)*skip_window+j] = data[target]
  return batch,label
    
print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_CBOW_batch(batch_size=8, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['anarchism', 'as', 'as', 'term', 'term', 'abuse', 'abuse', 'used']
#     labels: ['originated', 'originated', 'a', 'a', 'of', 'of', 'first', 'first']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['originated', 'anarchism', 'a', 'term', 'a', 'as', 'of', 'abuse']
#     labels: ['as', 'as', 'as', 'as', 'term', 'term', 'term', 'term']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.273611
# Nearest to s: speculated, evolutionary, shading, compliment, bulging, minimalist, alcindor, organizes,
# Nearest to that: projected, landed, baltic, nard, trying, shangri, polarized, topical,
# Nearest to however: honorable, lacaille, gears, ceremony, tire, peloponnese, oppositions, giraffe,
# Nearest to six: freyr, malatesta, dunst, underpinning, distillery, hints, oddity, chaste,
# Nearest to his: punter, vikernes, barons, carew, richthofen, dagger, pitted, proves,
# Nearest to over: functional, casualties, frenchmen, sancta, restart, ow, melle, serre,
# Nearest to are: mescaline, lovejoy, stds, correspondences, henchmen, disparage, mother, nawaf,
# Nearest to use: succumbed, murdoc, chang, midair, harrisburg, paralleling, owen, crusader,
# Nearest to seven: sang, shirkuh, sram, receive, flamsteed, ideas, chera, polynomials,
# Nearest to many: authenticity, settlements, egyptologist, dramatised, cp, lupercalia, axioms, osteoporosis,
# Nearest to was: alberta, rational, declassified, xxxviii, masoretic, suggest, hurl, invader,
# Nearest to will: enchantment, antilles, paladin, custom, sulpicius, boot, accented, nemesis,
# Nearest to during: nonconfirmative, goldstein, macho, degas, ligand, imitate, kantele, season,
# Nearest to so: residents, disparage, pronounces, sayyaf, fragmentary, wednesday, heartbeat, annalen,
# Nearest to from: queene, elbridge, lavos, chester, appellate, euboea, roof, parrots,
# Nearest to not: breakthroughs, lande, moat, vanguard, vistula, remedy, groening, egan,
# Average loss at step 2000: 4.353988
# Average loss at step 4000: 3.870200
# Average loss at step 6000: 3.792293
# Average loss at step 8000: 3.683979
# Average loss at step 10000: 3.613889
# Nearest to s: his, and, quarterfinals, eden, grain, harrisburg, brancusi, organizes,
# Nearest to that: it, this, which, eradicate, timestamp, rennie, pelts, paced,
# Nearest to however: honorable, ceremony, oppositions, lacaille, tire, gears, ammonium, breezes,
# Nearest to six: eight, five, four, seven, three, nine, zero, two,
# Nearest to his: their, the, its, s, theorems, jacksonville, transferable, polynesian,
# Nearest to over: bucharest, drug, melle, walsh, different, chopin, sheila, oppress,
# Nearest to are: were, is, have, lovejoy, dtds, ladyland, was, consulship,
# Nearest to use: succumbed, maja, entails, bp, hazard, bernadette, intercept, exclusively,
# Nearest to seven: eight, six, three, nine, four, five, zero, two,
# Nearest to many: some, various, rhetoric, elbl, those, reentry, most, gur,
# Nearest to was: is, had, were, has, became, by, been, landscapes,
# Nearest to will: can, could, fingerprints, may, enchantment, diadem, must, antilles,
# Nearest to during: stimulated, afro, season, imitate, uncivilized, premature, hadassah, yag,
# Nearest to so: residents, sardonic, disparage, dealt, annalen, dams, gonzalo, upstream,
# Nearest to from: in, of, on, towards, by, between, outflow, through,
# Nearest to not: it, they, egan, there, britten, medicare, knoxville, still,
# Average loss at step 12000: 3.604760
# Average loss at step 14000: 3.573190
# Average loss at step 16000: 3.410849
# Average loss at step 18000: 3.457783
# Average loss at step 20000: 3.540657
# Nearest to s: eden, lakeland, dunne, ugo, elliot, wrapper, thomas, eager,
# Nearest to that: which, however, but, following, this, neoclassical, when, radek,
# Nearest to however: but, honorable, that, oppositions, ceremony, when, ammonium, democritus,
# Nearest to six: five, eight, seven, nine, three, four, zero, two,
# Nearest to his: their, her, its, the, transferable, reminder, roast, tories,
# Nearest to over: drug, bucharest, chasing, omnivorous, slough, walsh, diamondbacks, pseudopods,
# Nearest to are: were, is, have, lovejoy, poised, other, ladyland, prematurely,
# Nearest to use: succumbed, maja, bp, entails, hazard, droughts, olde, jewels,
# Nearest to seven: eight, four, six, five, nine, three, zero, two,
# Nearest to many: some, these, various, several, those, most, all, other,
# Nearest to was: is, had, has, were, became, been, does, recordable,
# Nearest to will: can, could, would, may, must, should, to, miscellany,
# Nearest to during: after, afro, premature, mai, at, godard, occlusion, flanagan,
# Nearest to so: residents, pronounces, upstream, sardonic, disparage, infringes, annalen, creek,
# Nearest to from: through, between, towards, into, within, in, under, by,
# Nearest to not: it, they, also, to, britten, often, still, cellists,
# Average loss at step 22000: 3.502825
# Average loss at step 24000: 3.490943
# Average loss at step 26000: 3.479291
# Average loss at step 28000: 3.480317
# Average loss at step 30000: 3.508673
# Nearest to s: his, whose, hamar, circumventing, simplex, thomas, greensboro, visually,
# Nearest to that: which, this, but, however, when, if, what, radek,
# Nearest to however: but, when, honorable, that, although, mitigated, though, tutored,
# Nearest to six: eight, four, seven, five, nine, three, two, zero,
# Nearest to his: their, her, its, s, the, transferable, polynesian, jacksonville,
# Nearest to over: bucharest, drug, spike, package, sheila, morihei, pseudopods, meditator,
# Nearest to are: were, is, have, include, these, contain, commonly, caps,
# Nearest to use: hoo, succumbed, dictated, support, quad, purposes, jewels, dobson,
# Nearest to seven: eight, five, nine, four, six, three, zero, two,
# Nearest to many: some, several, these, various, most, those, their, all,
# Nearest to was: is, became, were, had, has, been, stabbing, be,
# Nearest to will: can, would, could, may, must, should, might, discharged,
# Nearest to during: in, after, at, by, mega, afro, autonegotiation, on,
# Nearest to so: upstream, pronounces, residents, infringes, if, sardonic, situ, allegations,
# Nearest to from: into, through, in, between, under, on, towards, lonsdaleite,
# Nearest to not: still, they, it, affords, often, britten, plausible, now,
# Average loss at step 32000: 3.499431
# Average loss at step 34000: 3.492734
# Average loss at step 36000: 3.454118
# Average loss at step 38000: 3.301745
# Average loss at step 40000: 3.428300
# Nearest to s: his, pipelined, whose, syllabus, dunne, suebi, evolutionary, wattle,
# Nearest to that: which, however, what, this, but, it, paced, apparently,
# Nearest to however: but, that, though, although, honorable, while, mitigated, which,
# Nearest to six: five, seven, four, eight, three, nine, two, one,
# Nearest to his: their, her, its, the, s, transferable, my, kidder,
# Nearest to over: bucharest, drug, about, encodes, spike, minas, bamberger, meditator,
# Nearest to are: were, is, have, lovejoy, contain, these, be, while,
# Nearest to use: support, hoo, periods, dictated, kris, purposes, olde, sybil,
# Nearest to seven: eight, five, six, nine, four, three, zero, two,
# Nearest to many: some, several, these, various, those, most, administers, their,
# Nearest to was: is, became, were, had, has, been, irredentist, be,
# Nearest to will: can, could, would, may, must, should, might, shall,
# Nearest to during: after, in, at, war, austen, afro, on, when,
# Nearest to so: upstream, residents, pronounces, bombers, infringes, morally, annalen, if,
# Nearest to from: through, in, into, of, cryopreservation, towards, between, under,
# Nearest to not: still, they, it, never, often, affords, cellists, plausible,
# Average loss at step 42000: 3.437661
# Average loss at step 44000: 3.454139
# Average loss at step 46000: 3.448251
# Average loss at step 48000: 3.351324
# Average loss at step 50000: 3.386079
# Nearest to s: and, his, activation, planing, whose, heinkel, pointy, robins,
# Nearest to that: which, however, but, this, radek, polarized, apparently, what,
# Nearest to however: but, although, that, though, while, honorable, when, mitigated,
# Nearest to six: eight, four, seven, five, nine, three, two, zero,
# Nearest to his: their, her, its, my, the, your, transferable, s,
# Nearest to over: bucharest, meditator, drug, bamberger, ism, sheila, negative, riyadh,
# Nearest to are: were, is, have, these, although, be, was, commonly,
# Nearest to use: periods, support, dictated, hoo, kris, purposes, cusp, number,
# Nearest to seven: eight, nine, six, four, three, five, zero, two,
# Nearest to many: some, several, these, various, those, most, both, much,
# Nearest to was: is, became, were, has, had, be, been, irredentist,
# Nearest to will: would, could, can, may, must, should, might, shall,
# Nearest to during: in, after, at, war, ves, when, of, following,
# Nearest to so: if, then, infringes, residents, upstream, pronounces, hormones, annalen,
# Nearest to from: through, into, between, in, within, across, towards, and,
# Nearest to not: still, they, cellists, never, now, instinctive, almost, usually,
# Average loss at step 52000: 3.436518
# Average loss at step 54000: 3.422396
# Average loss at step 56000: 3.441177
# Average loss at step 58000: 3.394812
# Average loss at step 60000: 3.394478
# Nearest to s: whose, extraterrestrial, elliot, his, pairwise, ludicrous, planing, hamar,
# Nearest to that: which, however, what, this, it, but, there, polarized,
# Nearest to however: but, although, that, though, since, which, mitigated, while,
# Nearest to six: eight, four, nine, five, seven, three, zero, one,
# Nearest to his: her, their, its, my, your, transferable, s, multistage,
# Nearest to over: sheila, meditator, through, bucharest, after, encodes, gibeon, earnestly,
# Nearest to are: were, is, have, including, tend, commonly, be, these,
# Nearest to use: kris, periods, support, purposes, commonsense, most, olde, amounts,
# Nearest to seven: eight, six, four, nine, five, three, zero, one,
# Nearest to many: some, several, various, these, those, most, other, both,
# Nearest to was: is, became, had, has, were, be, irredentist, recordable,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to during: after, in, although, following, until, before, when, at,
# Nearest to so: if, residents, situ, then, infringes, hormones, pronounces, grid,
# Nearest to from: through, into, towards, between, within, feldspar, in, under,
# Nearest to not: still, now, actually, usually, never, they, almost, i,
# Average loss at step 62000: 3.238563
# Average loss at step 64000: 3.262721
# Average loss at step 66000: 3.403879
# Average loss at step 68000: 3.392305
# Average loss at step 70000: 3.359818
# Nearest to s: whose, planing, dunne, visually, must, my, horrors, hangout,
# Nearest to that: which, however, what, but, this, polarized, shangri, often,
# Nearest to however: but, although, that, while, though, when, where, mitigated,
# Nearest to six: eight, seven, four, nine, five, three, zero, two,
# Nearest to his: her, their, its, your, my, multistage, whose, our,
# Nearest to over: sheila, meditator, encodes, about, tata, off, through, earnestly,
# Nearest to are: were, is, have, include, although, contain, including, these,
# Nearest to use: purposes, support, commonsense, periods, kris, call, cusp, most,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to many: some, several, various, these, most, those, all, both,
# Nearest to was: is, were, has, had, became, been, be, amd,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to during: after, in, before, until, since, following, throughout, although,
# Nearest to so: then, infringes, residents, hormones, pronounces, situ, grid, upstream,
# Nearest to from: into, through, towards, between, across, sectarianism, within, feldspar,
# Nearest to not: still, now, never, actually, almost, affords, they, cellists,
# Average loss at step 72000: 3.376342
# Average loss at step 74000: 3.346807
# Average loss at step 76000: 3.312734
# Average loss at step 78000: 3.353040
# Average loss at step 80000: 3.376168
# Nearest to s: whose, allen, planing, isbn, visually, ludicrous, layered, doublespeak,
# Nearest to that: which, however, polarized, detector, where, restricts, what, this,
# Nearest to however: but, although, that, though, while, when, where, mitigated,
# Nearest to six: four, five, seven, eight, three, nine, zero, two,
# Nearest to his: her, their, its, your, my, our, the, kidder,
# Nearest to over: meditator, about, sheila, gibeon, off, encodes, through, around,
# Nearest to are: were, is, although, include, have, including, those, tend,
# Nearest to use: support, commonsense, call, kris, periods, accredited, amounts, purposes,
# Nearest to seven: six, eight, five, nine, four, three, zero, one,
# Nearest to many: some, several, various, these, most, those, numerous, both,
# Nearest to was: is, became, were, has, had, been, irredentist, being,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to during: after, before, in, when, until, although, throughout, despite,
# Nearest to so: pronounces, situ, hormones, then, residents, infringes, if, morally,
# Nearest to from: through, into, feldspar, between, within, across, in, towards,
# Nearest to not: still, now, never, actually, affords, almost, they, it,
# Average loss at step 82000: 3.407221
# Average loss at step 84000: 3.407455
# Average loss at step 86000: 3.390555
# Average loss at step 88000: 3.354135
# Average loss at step 90000: 3.363028
# Nearest to s: his, whose, saddles, her, my, planing, adrienne, dances,
# Nearest to that: which, however, shangri, restricts, what, but, detector, polarized,
# Nearest to however: but, although, though, that, while, and, furthermore, especially,
# Nearest to six: eight, seven, five, four, nine, three, zero, two,
# Nearest to his: her, their, its, my, your, our, s, the,
# Nearest to over: about, meditator, off, sheila, encodes, through, gibeon, around,
# Nearest to are: were, is, include, these, tend, although, have, contain,
# Nearest to use: support, commonsense, purposes, accredited, call, periods, presence, most,
# Nearest to seven: eight, four, six, five, nine, three, one, zero,
# Nearest to many: some, several, various, these, numerous, all, those, few,
# Nearest to was: is, became, had, were, has, be, been, being,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to during: after, before, until, in, although, when, at, through,
# Nearest to so: infringes, too, julie, pronounces, before, if, hormones, then,
# Nearest to from: into, through, towards, across, feldspar, under, after, between,
# Nearest to not: still, never, actually, we, they, almost, now, egan,
# Average loss at step 92000: 3.396922
# Average loss at step 94000: 3.249973
# Average loss at step 96000: 3.358755
# Average loss at step 98000: 3.241608
# Average loss at step 100000: 3.357200
# Nearest to s: whose, his, allen, greensboro, my, her, the, dances,
# Nearest to that: which, however, what, ceremonially, detector, mennonites, restricts, eradicate,
# Nearest to however: but, although, though, that, especially, while, where, and,
# Nearest to six: four, seven, eight, five, nine, three, two, zero,
# Nearest to his: her, their, its, my, your, our, the, s,
# Nearest to over: sheila, meditator, about, off, encodes, within, bucharest, through,
# Nearest to are: were, these, have, include, is, including, contain, tend,
# Nearest to use: support, periods, most, purposes, boiling, commonsense, presence, subtended,
# Nearest to seven: eight, four, nine, six, five, zero, three, two,
# Nearest to many: several, some, various, numerous, these, those, all, most,
# Nearest to was: is, became, has, were, had, when, been, although,
# Nearest to will: would, could, can, must, may, should, might, cannot,
# Nearest to during: after, in, before, at, until, although, despite, throughout,
# Nearest to so: then, too, pronounces, if, lamiales, barium, brownish, situ,
# Nearest to from: into, in, through, austen, across, within, towards, sectarianism,
# Nearest to not: never, almost, still, they, now, actually, you, currently,
